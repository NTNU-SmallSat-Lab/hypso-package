# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../../hypso-package-new')
from hypso.hypso1 import Hypso1
from hypso.hypso2 import Hypso2

# %%
bands_h2 = np.load('../hypso2_calibration/hypso2_calibration/data/spectral_bands_HYPSO-2.npz')['arr_0']
rad_h2 = np.load('../hypso2_calibration/hypso2_calibration/data/h2_radiometric_calibration_matrix_wide.npz')['arr_0']
# rad_h2_2 = np.load('../hypso2_calibration/hypso2_calibration/data/h2_radiometric_calibration_matrix_wide-2.npz')['arr_0']

print(bands_h2)
plt.imshow(rad_h2)
# plt.figure()
# plt.imshow(rad_h2_2)

# print(np.array_equal(rad_h2, rad_h2_2))
# Out:
# [379.8273177  383.35406375 386.87964394 390.40405827 393.92730673
#  397.44938932 400.97030605 404.49005691 408.0086419  411.52606103
#  415.0423143  418.5574017  422.07132323 425.5840789  429.0956687
#  432.60609264 436.11535071 439.62344292 443.13036926 446.63612974
#  450.14072435 453.64415309 457.14641597 460.64751298 464.14744413
#  467.64620941 471.14380883 474.64024238 478.13551006 481.62961188
#  485.12254784 488.61431793 492.10492215 495.59436051 499.082633
#  502.56973963 506.05568039 509.54045529 513.02406432 516.50650748
#  519.98778478 523.46789621 526.94684178 530.42462149 533.90123532
#  537.37668329 540.8509654  544.32408164 547.79603202 551.26681653
#  554.73643517 558.20488795 561.67217486 565.13829591 568.60325109
#  572.06704041 575.52966386 578.99112144 582.45141316 585.91053902
#  589.368499   592.82529313 596.28092139 599.73538378 603.1886803
#  606.64081097 610.09177576 613.54157469 616.99020776 620.43767495
# ...
